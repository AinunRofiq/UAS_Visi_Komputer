# %% [markdown]
# Sebelum kita memulai semuanya, mari kita mulai dengan mengimpor pustaka yang akan kita gunakan, seperti openCV, numpy, matplotlib, glob, dan skimage

# %%
#im#impor library yang diperlukan
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob

from skimage.color import rgb2gray
from skimage.feature import local_binary_pattern

# %% [markdown]
# Langkah selanjutnya adalah mendefinisikan fungsi untuk metode yang akan kita eksekusi nanti. Fungsi pertama di bawah ini adalah fungsi load_image(). Tujuan dari fungsi ini adalah untuk memuat dataset/gambar dari komputer lokal dan menyimpannya ke dalam sebuah array. Nilai yang dikembalikan oleh fungsi ini adalah sebuah array gambar

# %%
#membuat fungsi load_image
def load_image(arr):
    strr = "Datasets/*.jpeg"
    for file in glob.glob(strr):
        img=np.asarray(plt.imread(file))
        arr.append(img)
    return arr

# %% [markdown]
# Fungsi selanjutnya adalah fungsi preprocessing(). Fungsi ini bertujuan untuk memproses dataset kita menjadi gambar skala keabuan

# %%
#membuat fungsi preprocessing
def preprocessing(arr):
    arr_prep=[]
    for i in range(np.shape(arr)[0]):
        img=cv2.cvtColor(arr[i], cv2.COLOR_BGR2GRAY)
        arr_prep.append(img)
    return arr_prep

# %% [markdown]
# Fungsi selanjutnya yang harus didefinisikan adalah extractLBP(). Tujuan dari fungsi ini adalah mengembalikan 2 nilai. Nilai pertama adalah hasil ekstraksi tekstur dalam bentuk gambar. Dan nilai kedua adalah hasil ekstraksi tekstur dalam bentuk vektor.

# %%
#membuat fungsi extractLBP
def extractLBP(img):
    lbp = local_binary_pattern(img, 24,3, method="uniform")
    (hist, _) = np.histogram(lbp.ravel(),bins=np.arange(0, 27),range=(0, 26))
    hist = hist.astype("float")
    hist /= (hist.sum() + (1e-7))
    return lbp,hist

# %% [markdown]
# Fungsi terakhir adalah featureExtraction(). Fungsi ini bertujuan untuk mengembalikan array baru yang berisi tekstur yang diekstraksi, beserta vektornya.

# %%
#membuat fungsi featureextraction
def featureExtraction(arr):
    arr_feature=[]
    vector_feature=[]
    for i in range(np.shape(arr)[0]):
        lb,vektor = extractLBP(arr[i])
        arr_feature.append(lb)
        vector_feature.append(vektor)
    return arr_feature, vector_feature

# %% [markdown]
# Langkah selanjutnya adalah memuat dataset dan menyimpannya dalam array

# %%
#memuat dataset
data=[]
data=load_image(data)

# %% [markdown]
# Setelah memuat dataset, lalu melakukan proses rubah gambar ke greyscale

# %%
#merubah gambar ke greyscale
dataPreprocessed = preprocessing(data)

# %% [markdown]
# Tahap terakhir adalah mendapatkan hasil ekstraksi tekstur

# %%
#mendapatkan hasil ekstraksi
dataExtracted,vector = featureExtraction(dataPreprocessed)

# %%
#menampilkan hasi ekstraksi tekstur
print('Extraction Result')
fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(4,2,1)
ax1.set_title('Before')
ax1.set_axis_off()
ax1.imshow(data[0])

ax2 = fig.add_subplot(4,2,2)
ax2.set_title('After')
ax2.set_axis_off()
ax2.imshow(dataExtracted[0],cmap=plt.cm.gray)

ax3 = fig.add_subplot(4,2,3)
ax3.set_title('Before')
ax3.set_axis_off()
ax3.imshow(data[1],)

ax4 = fig.add_subplot(4,2,4)
ax4.set_title('After')
ax4.set_axis_off()
ax4.imshow(dataExtracted[1],cmap=plt.cm.gray)

ax5 = fig.add_subplot(4,2,5)
ax5.set_title('Before')
ax5.set_axis_off()
ax5.imshow(data[2])

ax6 = fig.add_subplot(4,2,6)
ax6.set_title('After')
ax6.set_axis_off()
ax6.imshow(dataExtracted[2],cmap=plt.cm.gray)
plt.show()
# Out:
# Extraction Result

# %%
#cetak vektor gambar
print("Vector of Image 1 :",vector[0])
print()
print("Vector of Image 2 :",vector[1])
print()
print("Vector of Image 3 :",vector[2])
# Out:
# Vector of Image 1 : [0.02268837 0.01671775 0.00949329 0.00545317 0.00406002 0.00402022
#  0.00423914 0.00529395 0.0066871  0.00873701 0.01116507 0.02432034
#  0.05570593 0.05244199 0.01247861 0.03043028 0.00722446 0.02941528
#  0.00726426 0.00748318 0.00630896 0.00812005 0.01134419 0.01990208
#  0.35875493 0.27025037]
#
# Vector of Image 2 : [0.02268837 0.01671775 0.00949329 0.00545317 0.00406002 0.00402022
#  0.00423914 0.00529395 0.0066871  0.00873701 0.01116507 0.02432034
#  0.05570593 0.05244199 0.01247861 0.03043028 0.00722446 0.02941528
#  0.00726426 0.00748318 0.00630896 0.00812005 0.01134419 0.01990208
#  0.35875493 0.27025037]
#
# Vector of Image 3 : [0.02268837 0.01671775 0.00949329 0.00545317 0.00406002 0.00402022
#  0.00423914 0.00529395 0.0066871  0.00873701 0.01116507 0.02432034
#  0.05570593 0.05244199 0.01247861 0.03043028 0.00722446 0.02941528
#  0.00726426 0.00748318 0.00630896 0.00812005 0.01134419 0.01990208
#  0.35875493 0.27025037]
